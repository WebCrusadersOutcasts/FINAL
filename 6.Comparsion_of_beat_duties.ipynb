# %%
import dask.dataframe as dd

# Load the dataset with Dask
df = dd.read_csv('Tool6.csv')

# Group the data by 'Year' and 'Beat_Name' to get the count of crimes
df_analyse = df.groupby(['Year', 'District_Name', 'Beat_Name']).size().reset_index()
df_analyse.columns = ['Year', 'District_Name', 'Beat_Name', 'Number of crimes']

# Compute the Dask dataframe to get the actual result
df_analyse = df_analyse.compute()

# Get unique years and districts for filtering
unique_years = df_analyse['Year'].unique()
unique_districts = df_analyse['District_Name'].unique()

# Get user input for preferred year and district
preferred_year = int(input("Enter the preferred year: "))
preferred_district = input("Enter the preferred district: ")

# Check if the preferred year and district exist in the dataset
if (preferred_year not in unique_years) or (preferred_district not in unique_districts):
    print("Data for the preferred year or district not found.")
else:
    # Filter the data based on user preferences
    filtered_data = df_analyse[(df_analyse['Year'] == preferred_year) & (df_analyse['District_Name'] == preferred_district)]

    if filtered_data.empty:
        print("No data found for the selected year and district.")
    else:
        # Rank the beats based on the number of crimes reported
        ranked_beats = filtered_data.sort_values(by='Number of crimes', ascending=False)

        # Print the ranking list
        print(f"Ranking of beats with the highest number of crimes for Year {preferred_year} and District {preferred_district}:")
        for rank, (beat, num_crimes) in enumerate(zip(ranked_beats['Beat_Name'], ranked_beats['Number of crimes']), start=1):
            print(f"Rank {rank}: {beat} - Number of Crimes: {num_crimes}")

        # Save the ranking list to a text file
        with open(f'crime_ranking_{preferred_year}_{preferred_district}.txt', 'w') as f:
            f.write(f"Ranking of beats with the highest number of crimes for Year {preferred_year} and District {preferred_district}:\n")
            for rank, (beat, num_crimes) in enumerate(zip(ranked_beats['Beat_Name'], ranked_beats['Number of crimes']), start=1):
                f.write(f"Rank {rank}: {beat} - Number of Crimes: {num_crimes}\n")

        print(f"Ranking for Year {preferred_year} and District {preferred_district} has been saved to 'crime_ranking_{preferred_year}_{preferred_district}.txt'.")
# Out:
# Enter the preferred year:  2019
# Enter the preferred district:  Bagalkot
# Ranking of beats with the highest number of crimes for Year 2019 and District Bagalkot:
# Rank 1: RURAL BEAT 4 - Number of Crimes: 108
# Rank 2: TOWN BEAT 1 - Number of Crimes: 101
# Rank 3: RURAL BEAT 3 - Number of Crimes: 70
# Rank 4: Rural Beat No 1 - Number of Crimes: 57
# Rank 5: BEAT NO 2 - Number of Crimes: 57
# Rank 6: RURAL BEAT 2 - Number of Crimes: 53
# Rank 7: Rural Beat No 2 - Number of Crimes: 52
# Rank 8: TOWN BEAT 4 - Number of Crimes: 45
# Rank 9: TOWN BEAT 2 - Number of Crimes: 42
# Rank 10: BEAT NO 6 - Number of Crimes: 42
# Rank 11: RURAL BEAT 1 - Number of Crimes: 41
# Rank 12: BEAT 5 - Number of Crimes: 38
# Rank 13: RURAL BEAT I - Number of Crimes: 38
# Rank 59: Mudhol Town Beat 1 - Number of Crimes: 17
# Rank 60: GALAGALI OP BEAT 1 - Number of Crimes: 17
# Rank 61: Mudhol Town Beat 6 - Number of Crimes: 16
# Rank 62: BEAT NO 5 - Number of Crimes: 16
# Rank 63: RURALBEAT5 - Number of Crimes: 16
# Rank 64: BEAT NO 5 RURAL - Number of Crimes: 16
# Rank 65: RURAL BEAT NO 04 - Number of Crimes: 16
# Rank 66: BEVOOR OP BEAT NO 2 - Number of Crimes: 16
# Rank 67: RURAL BEAT NO 03 - Number of Crimes: 15
# Rank 68: NANDAVADAGI 0P BEAT NO 1 - Number of Crimes: 15
# Rank 69: BEAT 05 - Number of Crimes: 15
# Rank 70: Rural Beat No 3 - Number of Crimes: 14
# Rank 71: Rural Beat No 5 - Number of Crimes: 14
# Rank 72: RURAL BEAT NO 01 - Number of Crimes: 14
# Rank 73: BEAT 4 - Number of Crimes: 13
# Rank 74: TOWN BEAT NO 02 - Number of Crimes: 13
# Rank 75: RURAL BEAT NO 1 - Number of Crimes: 13
# Rank 76: TOWN BEAT NO 1 - Number of Crimes: 13
# Rank 77: TOWN BEAT NO 4 - Number of Crimes: 13
# Rank 78: TOWN BEAT NO 6 - Number of Crimes: 13
# Rank 79: RABAKAVI TOWN BEAT 1 - Number of Crimes: 13
# Rank 80: BEAT NO 8 RURAL - Number of Crimes: 12
# Rank 81: MHALINGPUR TOWN BEAT 1 - Number of Crimes: 12
# Rank 82: TERDAL RURAL BEAT 1 - Number of Crimes: 12
# Rank 83: BEAT NO 6 RURAL - Number of Crimes: 12
# Rank 84: BEAT 6 - Number of Crimes: 12
# Rank 85: TOWN BEAT NO 2 - Number of Crimes: 12
# Rank 86: TOWN BEAT NO 5 - Number of Crimes: 12
# Rank 87: RURAL BEAT NO 5 - Number of Crimes: 11
# Rank 88: TOWN BEAT NO 01 - Number of Crimes: 11
# Rank 89: 01 - Number of Crimes: 11
# Rank 90: VIDYAGIRI - Number of Crimes: 11
# Rank 91: GALAGALI OP BEAT 2 - Number of Crimes: 11
# Rank 92: BEAT 9 - Number of Crimes: 11
# Rank 93: BEAT 7 - Number of Crimes: 10
# Rank 94: 02 - Number of Crimes: 10
# Rank 95: RURALBEAT6 - Number of Crimes: 10
# Rank 96: OP BEAT NO 1 - Number of Crimes: 10
# Rank 97: BEAT 01 - Number of Crimes: 10
# Rank 98: RURAL BEAT 5 - Number of Crimes: 10
# Rank 99: BEAT NO 3 - Number of Crimes: 10
# Rank 100: BEAT NO 8 - Number of Crimes: 9
# Rank 101: BEAT NO 10 RURAL - Number of Crimes: 9
# Rank 102: RURAL BEAT NO 2 - Number of Crimes: 9
# Rank 103: Mudhol Town Beat 2 - Number of Crimes: 9
# Rank 104: TERADAL RURAL BEAT 2 - Number of Crimes: 9
# Rank 105: NAVANAGAR PS - Number of Crimes: 9
# Rank 106: BEAT NO 9 RURAL - Number of Crimes: 8
# Rank 107: RURAL BEAT NO 4 - Number of Crimes: 8
# Rank 108: Mudhol Town Beat 8 - Number of Crimes: 8
# Rank 109: GUDUR TOWN BEAT NO 21 - Number of Crimes: 8
# Rank 110: OP RURAL BEAT NO 28 - Number of Crimes: 8
# Rank 111: Mudhol Town Beat 3 - Number of Crimes: 8
# Rank 112: BEAT 06 - Number of Crimes: 7
# Rank 113: RURAL BEAT NO 02 - Number of Crimes: 7
# Rank 114: NANDAVADAGI OP BEAT NO 2 - Number of Crimes: 7
# Rank 115: BEAT NO 4 RURAL - Number of Crimes: 7
# Rank 116: 04 - Number of Crimes: 7
# Rank 117: BEAT 2 - Number of Crimes: 6
# Rank 118: MAHALINGPUR TOWN BEAT 2 - Number of Crimes: 6
# Rank 119: Bagalkot RL - Number of Crimes: 6
# Rank 120: TOWN  BEAT  2 - Number of Crimes: 5
# Rank 121: RABAKAVI TOWN BEAT 2 - Number of Crimes: 5
# Rank 122: MAHALINGPUR TOWN BEAT 3 - Number of Crimes: 5
# Rank 123: GUDUR OP BEAT NO 24 - Number of Crimes: 5
# Rank 124: RABAKAVI RURAL BEAT 1 - Number of Crimes: 5
# Rank 125: 06 - Number of Crimes: 4
# Rank 126: BEAT NO 12 RURAL - Number of Crimes: 4
# Rank 127: NAVANAGAR PS LIMITS - Number of Crimes: 3
# Rank 128: Mudhol Town Beat 5 - Number of Crimes: 3
# Rank 129: BILAGI PS LIMITS - Number of Crimes: 3
# Rank 130: GULEDAGUDDA PS LIMITS - Number of Crimes: 2
# Rank 131: MUDHOL PS LIMITS - Number of Crimes: 2
# Rank 132: BEAT NO 7 RURAL - Number of Crimes: 2
# Rank 133: Bagalkot Navanagar - Number of Crimes: 2
# Rank 134: BAGALKOT RURAL PS - Number of Crimes: 2
# Rank 135: Aminagad PS Limits - Number of Crimes: 2
# Rank 136: Banahatti PS LIMITS - Number of Crimes: 2
# Rank 137: LOKAPUR TOWN BEAT 1 - Number of Crimes: 1
# Rank 138: BEAT NO 7 - Number of Crimes: 1
# Rank 139: MAHALINGAPUR PS LIMITS - Number of Crimes: 1
# Rank 140: Badami ps - Number of Crimes: 1
# Rank 141: Mudhol Town Beat 4 - Number of Crimes: 1
# Rank 142: BAGALKOT TOWN PS - Number of Crimes: 1
# Rank 143: BADAMI PS - Number of Crimes: 1
# Rank 144: SAVALAGI PS - Number of Crimes: 1
# Rank 145: Other - Number of Crimes: 1
# Ranking for Year 2019 and District Bagalkot has been saved to 'crime_ranking_2019_Bagalkot.txt'.
